# %% [markdown]
# # Problem 1

# %% [markdown]
# ![1:24_tree.png](attachment:d600cb36-ae62-418b-9daa-657bef3897dc.png)

# %% [markdown]
# # Problem 2

# %%
# The CSCI_1070_Course is a local folder on my desktop, and Connor_CSCI_1070 is one of two 
# folders within it. This Connor_CSCI_1070 folder is also linked to my repo, meaning I've git add,
# committed, and pushed all the files——syllabus, class notes, README.md, textbook notes, warmups, and 
# first homework——in it. The second of the two folders under CSCI_1070_Course is csci_1070, Professor 
# McKenzie's repo, from which I git pulled the README.md and homework_1_questions.ipynb.

# %% [markdown]
# # Problem 3

# %%
months = ["January","February","March","April","May","June","July","August","September","October","November","December"]
birth_month = "January"
for month in months:
    if month == birth_month:
        print('Jais my birthday')
    else:
        print(month)
