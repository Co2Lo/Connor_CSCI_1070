# %%
import pandas as pd
import numpy as np
# Out:
# /var/folders/jq/xzwg3k5d0nqb3574ynkvzc740000gn/T/ipykernel_98573/2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
loans_df = pd.read_csv('loans_full_schema.csv')

# %%
loans_df.head()
# Out:
#                  emp_title  emp_length state homeownership  annual_income  \
# 0  global config engineer          3.0    NJ      MORTGAGE        90000.0
# 1   warehouse office clerk        10.0    HI          RENT        40000.0
# 2                 assembly         3.0    WI          RENT        40000.0
# 3         customer service         1.0    PA          RENT        30000.0
# 4     security supervisor         10.0    CA          RENT        35000.0
#
#    verified_income  debt_to_income  annual_income_joint  \
# 0         Verified           18.01                  NaN
# 1     Not Verified            5.04                  NaN
# 2  Source Verified           21.15                  NaN
# 3     Not Verified           10.16                  NaN
# 4         Verified           57.96              57000.0
#
#   verification_income_joint  debt_to_income_joint  ...  sub_grade  \
# 0                       NaN                   NaN  ...         C3
# ...

# %% [markdown]
# Hypothesis: Lenders with an income >100k, a low debt-to-income ratio, and good credit will have more fufilled loans than anyone else.

# %%
df_clothes = pd.DataFrame(data = [['green','M', 10,'shirt'],
                                  ['red', 'M', 60, 'sweatshirt'],
                                  ['black', 'M', 120, 'shoes']])

df_clothes.columns = ['color', 'size', 'price', 'type']
df_clothes
# Out:
#    color size  price        type
# 0  green    M     10       shirt
# 1    red    M     60  sweatshirt
# 2  black    M    120       shoes

# %%
#can convert categorical values to numerical
# size is ordinal so ite can easily encoded
size_map = {'S':1, 'M':2, 'L': 3}
df_clothes['size'] = df_clothes['size'].map(size_map)
df_clothes
# Out:
#    color  size  price        type
# 0  green     2     10       shirt
# 1    red     2     60  sweatshirt
# 2  black     2    120       shoes

# %%
# Nominal values
# Pip insall scikit-learn
from sklearn.preprocessing import LabelEncoder
class_labels = LabelEncoder()
df_clothes['types'] = class_labels.fit_transform(df_clothes['type'].values)
df_clothes
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 3
#       1 # Nominal values
#       2 # Pip insall scikit-learn
# ----> 3 from sklearn.preprocessing import LabelEncoder
#       4 class_labels = LabelEncoder()
#       5 df_clothes['types'] = class_labels.fit_transform(df_clothes['type'].values)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# One hot encoding - easiest
# Won't work is you have data that's already numerical
df_clothes = pd.get_dummies(df_clothes[['color', 'size', 'price']])
df_clothes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 3
#       1 # One hot encoding - easiest
#       2 # Won't work is you have data that's already numerical
# ----> 3 df_clothes = pd.get_dummies(df_clothes[['color', 'size', 'price']])
#       4 df_clothes
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094     if is_iterator(key):
#    4095         key = list(key)
# -> 4096     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4098 # take() does not accept boolean indexers
#    4099 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:6199, in Index._get_indexer_strict(self, key, axis_name)
#    6196 else:
#    6197     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...
